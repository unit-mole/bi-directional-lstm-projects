# %% [markdown]
# # Emotion Detection using BiLSTM with Attention
#
# This notebook is the portfolio-facing experiment runner. Core logic lives in `src/` so the same preprocessing, model architecture, evaluation, and inference code is reused by scripts and Streamlit.
#
# > **Responsible use:** This is an educational model. Do not submit private or sensitive text or use predictions as definitive emotional truth.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT))
from src.config import TrainingConfig
from src.data_preprocessing import load_and_clean_dataset
from src.model_training import train_pipeline

# %% [markdown]
# ## 1. Load and audit the dataset

# %%
DATA_PATH = PROJECT_ROOT / 'data' / 'emotion_dataset.csv'
frame, audit = load_and_clean_dataset(DATA_PATH)
display(frame.head())
audit.to_dict()

# %% [markdown]
# ## 2. Review class support
#
# The bundled 10-row file is a placeholder and is not large enough for credible stratified training. Replace `DATA_PATH` with a complete licensed dataset before running the next cell.

# %%
frame['emotion'].value_counts()

# %% [markdown]
# ## 3. Train the production attention architecture

# %%
# Set this to your complete licensed dataset before execution.
FULL_DATA_PATH = PROJECT_ROOT / 'data' / 'emotion_dataset_full.csv'
config = TrainingConfig(epochs=15, batch_size=32)
# metadata = train_pipeline(FULL_DATA_PATH, config=config)
# metadata

# %% [markdown]
# ## 4. Expected architecture
#
# `Text → tokenizer → padded sequence → embedding → Bidirectional LSTM (return_sequences=True) → temporal attention → dense layer → softmax`
